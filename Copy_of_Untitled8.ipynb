# %% [markdown]
# <a href="https://colab.research.google.com/github/Anugraha359/AUTISM-DETECTION/blob/main/Copy_of_Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1
# Out:
# 2

# %%
7-6
# Out:
# 1

# %%
9+8
# Out:
# 17

# %%
x=3
y=4
z=x+y
print(z)
# Out:
# 7

# %%
x=3
type(x)
y="smile"
type(y)
# Out:
# str

# %%
x=4
y=6
add=x+y
sub=x-y
mul=x*y
div=x**y
print("Sum of",x,"and",y,"is ", add)
print("difference of",x,"and",y,"is ", sub)
print("multiplication of",x,"and",y,"is ", mul)
print("division of",x,"and",y,"is ", div)
# Out:
# Sum of 4 and 6 is  10
# difference of 4 and 6 is  -2
# multiplication of 4 and 6 is  24
# division of 4 and 6 is  4096
